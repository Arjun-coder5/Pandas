# %% [markdown]
# <a href="https://colab.research.google.com/github/Arjun-coder5/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Pandas Start***
# A series is a 1 - D labled Array capable of holding any data type . The axis lable are collectively called the index.

# %% [markdown]
# **import pandas**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series from List :

# %%
# String
country = ['India','pak','USA','Nepal','ShriLanka']
pd.Series(country)
# Out:
# 0        India
# 1          pak
# 2          USA
# 3        Nepal
# 4    ShriLanka
# dtype: object

# %%
# Integer :
runs = [13,12,24,56,78,100]
pd.Series(runs)
# Out:
# 0     13
# 1     12
# 2     24
# 3     56
# 4     78
# 5    100
# dtype: int64

# %%
# Custom index :
marks = [45,34,23,45]
subject = ['maths','science','english','social']
pd.Series(marks,index= subject)
# Out:
# maths      45
# science    34
# english    23
# social     45
# dtype: int64

# %%
# Setting a Name :
marks  =pd.Series(marks,index= subject , name  = "Marks")
marks
# Out:
# maths      45
# science    34
# english    23
# social     45
# Name: Marks, dtype: int64

# %% [markdown]
# # ***Series from Dict :***

# %%
marks = {
    'maths' : 83,
    'english' :93,
    'Science' : 92
}

marks_series = pd.Series(marks,name = 'Marks')
marks_series
# Out:
# maths      83
# english    93
# Science    92
# Name: Marks, dtype: int64

# %% [markdown]
# # ***Series Attributes :***

# %%
# Size :
marks_series.size
# Out:
# 3

# %%
# dtype :
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name :
marks_series.name
# Out:
# 'Marks'

# %%
# is_unique :
# marks_series.is_unique
pd.Series([1,1,1,1]).is_unique
# Out:
# False

# %%
# index :
marks_series.index
# Out:
# Index(['maths', 'english', 'Science'], dtype='object')

# %%
# value :
marks_series.values
# Out:
# array([83, 93, 92])

# %% [markdown]
# # ***Series Using read_csv***

# %%
# With one column
subs = pd.read_csv('/content/subs.csv').squeeze("columns")
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# With two column
vk = pd.read_csv('/content/kohli_ipl.csv',index_col='match_no').squeeze('columns')
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('/content/bollywood.csv',index_col="movie").squeeze('columns')
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # ***Series Methods***

# %%
# head and Tail :
subs.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
vk.head(3)
# Out:
# match_no
# 1     1
# 2    23
# 3    13
# Name: runs, dtype: int64

# %%
vk.tail(7)
# Out:
# match_no
# 209    58
# 210    30
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
# Sample :
movies.sample()
# Out:
# movie
# Ugly (film)    Rahul Bhat
# Name: lead, dtype: object

# %%
# value_counts -> movies
movies.value_counts()
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
#  sort_values -> inplace
vk.sort_values(ascending=False).head(1).values[0]
# Out:
# np.int64(113)

# %%
# sort_index -> inplace -> movies
movies.sort_index()
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # ***Series Maths Methods***

# %%
# Count
vk.count()
# Out:
# np.int64(215)

# %%
# Sum -> product
subs.sum()
# Out:
# np.int64(49510)

# %%
# mean -> median -> mode -> std -> var
subs.mean()
print(vk.median())
print(movies.mode())
print(subs.std())
print(subs.var())
# Out:
# 24.0
# 0    Akshay Kumar
# Name: lead, dtype: object
# 62.67502303725269
# 3928.1585127201556

# %%
# min/max :
subs.max()
# Out:
# 396

# %%
# describe
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %% [markdown]
# # ***DataFrame***

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# creating a DataFrame :

# %%
data = {
    'Name': ['Alice','Anna','Peter','Linda'],
    'Location': ['New York','Paris','Berlin','London'],
    'Age': [24,24,52,43],
    'Salary': [50000,52000,60000,65000]
}
pd.DataFrame(data)
# Out:
#     Name  Location  Age  Salary
# 0  Alice  New York   24   50000
# 1   Anna     Paris   24   52000
# 2  Peter    Berlin   52   60000
# 3  Linda    London   43   65000

# %%
data_list = [
    ['Alice','New York',24,50000],
    ['Anna','Paris',24,52000],
    ['Peter','Berlin', 52,60000],
    ['Linda','London',43,65000]
]
df = pd.DataFrame(data_list,columns=['Name','Location','Age','Salary'])
df
# Out:
#     Name  Location  Age  Salary
# 0  Alice  New York   24   50000
# 1   Anna     Paris   24   52000
# 2  Peter    Berlin   52   60000
# 3  Linda    London   43   65000

# %%
df[["Name"]]
# Out:
#     Name
# 0  Alice
# 1   Anna
# 2  Peter
# 3  Linda

# %%
df["Designation"] = ["Doctor","Engineer","Doc","Eng"]
df
# Out:
#     Name  Location  Age  Salary Designation
# 0  Alice  New York   24   50000      Doctor
# 1   Anna     Paris   24   52000    Engineer
# 2  Peter    Berlin   52   60000         Doc
# 3  Linda    London   43   65000         Eng

# %%
df.drop("Designation",axis = 1,inline = True)
# Out:
#     Name  Location  Age  Salary
# 0  Alice  New York   24   50000
# 1   Anna     Paris   24   52000
# 2  Peter    Berlin   52   60000
# 3  Linda    London   43   65000

# %%
df.loc[[0,1]]
# Out:
#     Name  Location  Age  Salary Designation
# 0  Alice  New York   24   50000      Doctor
# 1   Anna     Paris   24   52000    Engineer

# %%
df.iloc[3]
# Out:
# Name            Linda
# Location       London
# Age                43
# Salary          65000
# Designation       Eng
# Name: 3, dtype: object
